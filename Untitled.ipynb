# %%
# load dataset
from pycaret.datasets import get_data
diabetes = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
#pip list

# %%
# init setup
from pycaret.classification import *
import matplotlib.pyplot as plt
clf1 = setup(data = diabetes, target = 'Class variable')

# creating a model
lr = create_model('lr')

# plot model
# Out:
# <style type="text/css">
# #T_05ede_row10_col0, #T_05ede_row10_col1, #T_05ede_row10_col2, #T_05ede_row10_col3, #T_05ede_row10_col4, #T_05ede_row10_col5, #T_05ede_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_05ede_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
# ...

# %%
df=pull()
print(df)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.7778  0.8105  0.4737  0.8182  0.6000  0.4609  0.4939
# 1       0.8333  0.8812  0.7368  0.7778  0.7568  0.6301  0.6307
# 2       0.7963  0.8627  0.5556  0.7692  0.6452  0.5075  0.5207
# 3       0.7778  0.8488  0.6111  0.6875  0.6471  0.4857  0.4875
# 4       0.7778  0.8056  0.6667  0.6667  0.6667  0.5000  0.5000
# 5       0.7222  0.8256  0.3889  0.6364  0.4828  0.3077  0.3251
# 6       0.7593  0.7917  0.5556  0.6667  0.6061  0.4348  0.4385
# 7       0.7736  0.7746  0.6111  0.6875  0.6471  0.4812  0.4830
# 8       0.7736  0.8206  0.5556  0.7143  0.6250  0.4664  0.4740
# 9       0.7736  0.8444  0.5000  0.7500  0.6000  0.4508  0.4688
# Mean    0.7765  0.8266  0.5655  0.7174  0.6277  0.4725  0.4822
# Std     0.0263  0.0312  0.0938  0.0557  0.0650  0.0750  0.0713

# %%
tuned_lr= tune_model(lr)
# Out:
# <style type="text/css">
# #T_6abd0_row10_col0, #T_6abd0_row10_col1, #T_6abd0_row10_col2, #T_6abd0_row10_col3, #T_6abd0_row10_col4, #T_6abd0_row10_col5, #T_6abd0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6abd0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
# ...

# %%
tuned_lr_itr= tune_model(lr, n_iter = 50)
# Out:
# <style type="text/css">
# #T_d6f0b_row10_col0, #T_d6f0b_row10_col1, #T_d6f0b_row10_col2, #T_d6f0b_row10_col3, #T_d6f0b_row10_col4, #T_d6f0b_row10_col5, #T_d6f0b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d6f0b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
# ...

# %%
tuned_lr_mtr= tune_model(lr, optimize = 'AUC')
# Out:
# <style type="text/css">
# #T_e17c9_row10_col0, #T_e17c9_row10_col1, #T_e17c9_row10_col2, #T_e17c9_row10_col3, #T_e17c9_row10_col4, #T_e17c9_row10_col5, #T_e17c9_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e17c9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
# ...

# %%
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_9eba5_row10_col0, #T_9eba5_row10_col1, #T_9eba5_row10_col2, #T_9eba5_row10_col3, #T_9eba5_row10_col4, #T_9eba5_row10_col5, #T_9eba5_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9eba5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
# ...

# %%
# tune model
tuned_dt = tune_model(dt, optimize = 'Recall')
# Out:
# <style type="text/css">
# #T_05176_row10_col0, #T_05176_row10_col1, #T_05176_row10_col2, #T_05176_row10_col3, #T_05176_row10_col4, #T_05176_row10_col5, #T_05176_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_05176_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
# ...

# %%
rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_87e34_row10_col0, #T_87e34_row10_col1, #T_87e34_row10_col2, #T_87e34_row10_col3, #T_87e34_row10_col4, #T_87e34_row10_col5, #T_87e34_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_87e34_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
# ...

# %%
fig = plt.figure(figsize=(25,20)) 
plot_model(lr, plot = 'feature', save=True, verbose=False, scale=1.1) 
plt.savefig('fileName.png')

# %%
import matplotlib.pyplot as plt
plt.figure().canvas.get_supported_filetypes()

# %%
# plot model
plot_model(lr, plot = 'auc')

# %%
# plot model
plot_model(lr, plot = 'auc',save=True)

# %%
# plot model
plot_model(lr, plot = 'confusion_matrix')

# %%
plot_model(lr, plot = 'confusion_matrix',save=True)

# %%
 get_config("prep_pipe")

# %%
dtype_object=get_config("prep_pipe").steps[0][1]
dtype_object

# %%
help(get_config)

# %%
plot_model(lr, plot = 'class_report')

# %%
plot_model(lr, plot = 'ks')

# %%
plot_model(lr, plot = 'ks',save=True)

# %%
plot_model(lr, plot = 'parameter',save=False)

# %%
plot_model(lr, plot = 'class_report',save=True)

# %%
import matplotlib.pyplot as plt

axes = plt.gca()

# %%
# plot model
plot_model(lr, plot = 'confusion_matrix', use_train_data = True)

# %%
plot_model(lr, plot = 'error',save=False, use_train_data = True)

# %%
plot_model(lr, plot = 'error',save=True)

# %%
from sklearn.cluster import MiniBatchKMeans
from yellowbrick.cluster import KElbowVisualizer

visualizer = KElbowVisualizer(MiniBatchKMeans(), k=(4,12))

visualizer.fit(X)
visualizer.show(outpath="kelbow_minibatchkmeans.png")

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

from yellowbrick.classifier import ROCAUC
from yellowbrick.datasets import load_spam
import os
from pathlib import Path
 
plot_dir='D:/Projects/Python/ModelValPycaret/static/media/'

# # Load the classification dataset
# X, y = load_spam()
from pycaret.datasets import get_data
X=diabetes.drop("Class variable", axis=1)
y=diabetes["Class variable"]

# Create the training and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Instantiate the visualizer with the classification model
model = LogisticRegression(multi_class="auto", solver="liblinear")
visualizer = ROCAUC(model, classes=["not_spam", "is_spam"])

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show(outpath= plot_dir  + "_yellowbauc.png")

# %%
import os
print(__file__)
print(os.path.join(os.path.dirname(__file__), '..'))
print(os.path.dirname(os.path.realpath(__file__)))
print(os.path.abspath(os.path.dirname(__file__)))

# %%
from pathlib import Path
print(__file__)
print(Path(__file__))
